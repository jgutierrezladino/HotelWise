# %%
import pandas as pd
import numpy as np
import random
from google.colab import drive

# %% [markdown]
# # DB FIX

# %% [markdown]
# ## Agregamos Amenities y Seguridad

# %% [markdown]
# MONTAJE DE ARCHIVOS GOOGLE DRIVE:

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
user_reviews_content = '/content/drive/MyDrive/Colab Notebooks/HotelWiseML/hoteles_unificado.xlsx'
user_reviews_dataset = pd.read_excel(user_reviews_content)

# %% [markdown]
# MONTAJE DE ARCHIVOS LOCAL:

# %%
user_reviews_content = 'hoteles_unificado.xlsx'
user_reviews_dataset = pd.read_excel(user_reviews_content)

# %%
user_reviews_dataset.head(2)
# Out:
#         name                                gmap_id   latitude  longitude  \
# 0  Palms Inn  0x88e77bee8518ceef:0xbbd071e414788286  28.510625 -81.418326
# 1  Palms Inn  0x88e77bee8518ceef:0xbbd071e414788286  28.510625 -81.418326
#
#   category  avg_rating  num_of_reviews  \
# 0    Hotel         2.8              18
# 1    Hotel         2.8              18
#
#                                                  url         County     City  \
# 0  https://www.google.com/maps/place//data=!4m2!3...  Orange County  Orlando
# 1  https://www.google.com/maps/place//data=!4m2!3...  Orange County  Orlando
#
#      State        Country                user_id           time  \
# 0  Florida  United States  118246347898887897540  1547363052901
# 1  Florida  United States  113381044260348711882  1548691460412
#
#                                                 text  \
# 0  I'm new to the area and needed a place to live...
# 1  This was previously a Ramada but was sold & be...
#
# ...

# %%
# Llenar la columna 'security' con valores aleatorios entre 5 y 10
user_reviews_dataset['security'] = np.random.randint(5, 11, size=len(user_reviews_dataset))

# %%
user_reviews_dataset.head(2)
# Out:
#         name                                gmap_id   latitude  longitude  \
# 0  Palms Inn  0x88e77bee8518ceef:0xbbd071e414788286  28.510625 -81.418326
# 1  Palms Inn  0x88e77bee8518ceef:0xbbd071e414788286  28.510625 -81.418326
#
#   category  avg_rating  num_of_reviews  \
# 0    Hotel         2.8              18
# 1    Hotel         2.8              18
#
#                                                  url         County     City  \
# 0  https://www.google.com/maps/place//data=!4m2!3...  Orange County  Orlando
# 1  https://www.google.com/maps/place//data=!4m2!3...  Orange County  Orlando
#
#      State        Country                user_id           time  \
# 0  Florida  United States  118246347898887897540  1547363052901
# 1  Florida  United States  113381044260348711882  1548691460412
#
#                                                 text  \
# 0  I'm new to the area and needed a place to live...
# 1  This was previously a Ramada but was sold & be...
#
# ...

# %%
# Lista de 30 amenidades
amenities_list = [
    'Pool', 'Gym', 'Restaurant', 'Bar', 'Spa',
    'Free Wi-Fi', 'Complimentary Breakfast', 'Room Service', 'Free Parking', '24-Hour Reception',
    'Business Center', 'Conference Room', 'Laundry Service', 'Daily Housekeeping', 'Air Conditioning',
    'Heating', 'Jacuzzi', 'Sauna', 'Hot Tub', 'Airport Shuttle Service',
    'Concierge Service', 'Accessible Accommodations', 'Family Rooms', 'Terrace or Garden',
    'Bicycle Rental Service', 'Beauty Salon', 'Luggage Storage', 'Children\'s Play Area',
    'Multilingual Staff', 'Soundproof Rooms'
]
# Definir función para seleccionar 5 amenidades al azar sin repetición
def select_random_amenities():
    return random.sample(amenities_list, k=5)

# Llenar la columna 'amenities' con 5 amenidades aleatorias
user_reviews_dataset['amenities'] = user_reviews_dataset.apply(lambda x: select_random_amenities(), axis=1)

# %%
user_reviews_dataset.head(2)
# Out:
#         name                                gmap_id   latitude  longitude  \
# 0  Palms Inn  0x88e77bee8518ceef:0xbbd071e414788286  28.510625 -81.418326
# 1  Palms Inn  0x88e77bee8518ceef:0xbbd071e414788286  28.510625 -81.418326
#
#   category  avg_rating  num_of_reviews  \
# 0    Hotel         2.8              18
# 1    Hotel         2.8              18
#
#                                                  url         County     City  \
# 0  https://www.google.com/maps/place//data=!4m2!3...  Orange County  Orlando
# 1  https://www.google.com/maps/place//data=!4m2!3...  Orange County  Orlando
#
#      State        Country                user_id           time  \
# 0  Florida  United States  118246347898887897540  1547363052901
# 1  Florida  United States  113381044260348711882  1548691460412
#
#                                                 text  \
# 0  I'm new to the area and needed a place to live...
# 1  This was previously a Ramada but was sold & be...
#
# ...

# %% [markdown]
# ###  Guardamos el df con las columnas necesarias para el análisis posterior

# %%
user_reviews_dataset_Final=user_reviews_dataset[['name','latitude','longitude','County', 'City', 'text','avg_rating','security', 'amenities']]

# %%
user_reviews_dataset_Final.rename(columns={'County':'county', 'City':'city', 'text': 'reviews'}, inplace=True)
# Out:
# <ipython-input-12-6f830242cb3f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_reviews_dataset_Final.rename(columns={'County':'county', 'City':'city', 'text': 'reviews'}, inplace=True)

# %%
user_reviews_dataset_Final.head()
# Out:
#         name   latitude  longitude         county     city  \
# 0  Palms Inn  28.510625 -81.418326  Orange County  Orlando
# 1  Palms Inn  28.510625 -81.418326  Orange County  Orlando
# 2  Palms Inn  28.510625 -81.418326  Orange County  Orlando
# 3  Palms Inn  28.510625 -81.418326  Orange County  Orlando
# 4  Palms Inn  28.510625 -81.418326  Orange County  Orlando
#
#                                              reviews  avg_rating  security  \
# 0  I'm new to the area and needed a place to live...         2.8        10
# 1  This was previously a Ramada but was sold & be...         2.8         5
# 2  Just checked in and found out that it is under...         2.8         5
# 3  I like the place. The place is massive, and su...         2.8        10
# 4  Awesome staff place is nice and clean rooms ar...         2.8         6
#
#                                            amenities
# 0  [Pool, Free Wi-Fi, Spa, Concierge Service, Air...
# ...

# %%
# Guardar DataFrame en un archivo Parquet
user_reviews_dataset_Final.to_parquet('hoteles_unificado.parquet')
